# %%
# Importing libraries
import torch
import torch.nn as nn
import torch.optim as opt
torch.set_printoptions(linewidth=120)
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
from itertools import product

# Helper functions
def get_num_correct(preds, labels):
    return preds.argmax(dim=1).eq(labels).sum().item()

# CNN Model
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=12, kernel_size=5)

        self.fc1 = nn.Linear(in_features=12*4*4, out_features=120)
        self.fc2 = nn.Linear(in_features=120, out_features=60)
        self.out = nn.Linear(in_features=60, out_features=10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, kernel_size = 2, stride = 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, kernel_size = 2, stride = 2)
        x = torch.flatten(x,start_dim = 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)

        return x

#Loading datasets
train_set = torchvision.datasets.FashionMNIST(root="./data",train = True, download=True,transform=transforms.ToTensor())
device = ("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
parameters = dict(
    lr = [0.01, 0.001],
    batch_size = [32,64,128],
    shuffle = [True, False]
)
param_values = [v for v in parameters.values()]

# Training Loop
for run_id, (lr,batch_size, shuffle) in enumerate(product(*param_values)):
    print("run id:", run_id + 1)
    model = CNN().to(device)
    train_loader = torch.utils.data.DataLoader(train_set,batch_size = batch_size, shuffle = shuffle)
    optimizer = opt.Adam(model.parameters(), lr= lr)
    criterion = torch.nn.CrossEntropyLoss()
    comment = f' batch_size = {batch_size} lr = {lr} shuffle = {shuffle}'
    tb = SummaryWriter(comment=comment)
    for epoch in range(5):
        total_loss = 0
        total_correct = 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            preds = model(images)

            loss = criterion(preds, labels)
            total_loss+= loss.item()
            total_correct+= get_num_correct(preds, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        tb.add_scalar("Loss", total_loss, epoch)
        tb.add_scalar("Correct", total_correct, epoch)
        tb.add_scalar("Accuracy", total_correct/ len(train_set), epoch)

        print("batch_size:",batch_size, "lr:",lr,"shuffle:",shuffle)
        print("epoch:", epoch, "total_correct:", total_correct, "loss:",total_loss)
    print("___________________________________________________________________")

    tb.add_hparams(
            {"lr": lr, "bsize": batch_size, "shuffle":shuffle},
            {
                "accuracy": total_correct/ len(train_set),
                "loss": total_loss,
            },
        )

tb.close()
# Out:
# run id: 1
# batch_size: 32 lr: 0.01 shuffle: True
# epoch: 0 total_correct: 47383 loss: 1051.7333302497864
# batch_size: 32 lr: 0.01 shuffle: True
# epoch: 1 total_correct: 50389 loss: 815.9296674132347
# batch_size: 32 lr: 0.01 shuffle: True
# epoch: 2 total_correct: 50878 loss: 778.099644638598
# batch_size: 32 lr: 0.01 shuffle: True
# epoch: 3 total_correct: 51016 loss: 758.2939350530505
# batch_size: 32 lr: 0.01 shuffle: True
# epoch: 4 total_correct: 51120 loss: 758.7454754151404
# ___________________________________________________________________
# run id: 2
# batch_size: 32 lr: 0.01 shuffle: False
# epoch: 0 total_correct: 6031 loss: 4320.352498054504
# batch_size: 32 lr: 0.01 shuffle: False
# epoch: 1 total_correct: 6004 loss: 4320.223387479782
# batch_size: 32 lr: 0.01 shuffle: False
# epoch: 2 total_correct: 6004 loss: 4320.222406625748
# batch_size: 32 lr: 0.01 shuffle: False
# epoch: 3 total_correct: 6004 loss: 4320.222248792648
# batch_size: 32 lr: 0.01 shuffle: False
# epoch: 4 total_correct: 6004 loss: 4320.222242355347
# ___________________________________________________________________
# run id: 3
# batch_size: 64 lr: 0.01 shuffle: True
# batch_size: 32 lr: 0.001 shuffle: False
# epoch: 0 total_correct: 44710 loss: 1240.27750146389
# batch_size: 32 lr: 0.001 shuffle: False
# epoch: 1 total_correct: 49969 loss: 849.459379568696
# batch_size: 32 lr: 0.001 shuffle: False
# epoch: 2 total_correct: 51612 loss: 714.167323179543
# batch_size: 32 lr: 0.001 shuffle: False
# epoch: 3 total_correct: 52509 loss: 635.8627607822418
# batch_size: 32 lr: 0.001 shuffle: False
# epoch: 4 total_correct: 53063 loss: 585.1250059828162
# ___________________________________________________________________
# run id: 9
# batch_size: 64 lr: 0.001 shuffle: True
# epoch: 0 total_correct: 43795 loss: 660.177917689085
# batch_size: 64 lr: 0.001 shuffle: True
# epoch: 1 total_correct: 50066 loss: 424.44445434212685
# batch_size: 64 lr: 0.001 shuffle: True
# epoch: 2 total_correct: 51527 loss: 364.2714523524046
# batch_size: 64 lr: 0.001 shuffle: True
# epoch: 3 total_correct: 52324 loss: 328.50893918424845
# batch_size: 64 lr: 0.001 shuffle: True
# epoch: 4 total_correct: 52866 loss: 307.432553909719
# ___________________________________________________________________
# run id: 10
# batch_size: 64 lr: 0.001 shuffle: False
# epoch: 0 total_correct: 43001 loss: 698.066376209259
# batch_size: 64 lr: 0.001 shuffle: False
# epoch: 1 total_correct: 49126 loss: 457.60171127319336
# batch_size: 64 lr: 0.001 shuffle: False
# epoch: 2 total_correct: 51024 loss: 385.69772686064243
# batch_size: 64 lr: 0.001 shuffle: False
# epoch: 3 total_correct: 51926 loss: 343.9816979467869
# batch_size: 64 lr: 0.001 shuffle: False
# epoch: 4 total_correct: 52479 loss: 319.17388840019703
# ___________________________________________________________________
# run id: 11
# batch_size: 128 lr: 0.001 shuffle: True
# epoch: 0 total_correct: 41138 loss: 390.4430332481861
# batch_size: 128 lr: 0.001 shuffle: True
# epoch: 1 total_correct: 47546 loss: 254.36243042349815
# batch_size: 128 lr: 0.001 shuffle: True
# epoch: 2 total_correct: 49808 loss: 219.1967495381832
# batch_size: 128 lr: 0.001 shuffle: True
# epoch: 3 total_correct: 50929 loss: 196.4540006071329
# batch_size: 128 lr: 0.001 shuffle: True
# epoch: 4 total_correct: 51692 loss: 181.1806593388319
# ___________________________________________________________________
# run id: 12
# batch_size: 128 lr: 0.001 shuffle: False
# epoch: 0 total_correct: 41671 loss: 376.03264370560646
# batch_size: 128 lr: 0.001 shuffle: False
# epoch: 1 total_correct: 48022 loss: 244.96536207199097
# batch_size: 128 lr: 0.001 shuffle: False
# epoch: 2 total_correct: 49978 loss: 214.1177774965763
# batch_size: 128 lr: 0.001 shuffle: False
# epoch: 3 total_correct: 51072 loss: 193.669449955225
# batch_size: 128 lr: 0.001 shuffle: False
# epoch: 4 total_correct: 51667 loss: 179.83893011510372
# ___________________________________________________________________
