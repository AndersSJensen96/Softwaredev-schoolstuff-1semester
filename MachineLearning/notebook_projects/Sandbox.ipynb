# %%
import torch

A = torch.tensor ([
[0, 2, 9],
[6, 5, 3],
])

B = torch.tensor ([
[4, 1, 3],
[1, 7, 8],
[4, 2, 8]
])

i = torch.tensor ([
[1, 0, 0],
[0, 1, 0],
[0, 0, 1]
])

#A*B
torch.matmul(A, B)

#B*B
torch.matmul(B,B)
# Out:
# tensor([[ 29,  17,  44],
#         [ 43,  66, 123],
#         [ 50,  34,  92]])
